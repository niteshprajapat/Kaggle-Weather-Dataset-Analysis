# %%
import pandas as pd

# %%
df = pd.read_csv("weatherHistory.csv")

# %%
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
df.tail()
# Out:
#                       Formatted Date        Summary Precip Type  \
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 96448        26.016667                 26.016667      0.43            10.9963
# 96449        24.583333                 24.583333      0.48            10.0947
# 96450        22.038889                 22.038889      0.56             8.9838
# 96451        21.522222                 21.522222      0.60            10.5294
# 96452        20.438889                 20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# ...

# %%
df.shape
# Out:
# (96453, 12)

# %%
df.size
# Out:
# 1157436

# %%
df.index
# Out:
# RangeIndex(start=0, stop=96453, step=1)

# %%
df.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
df.dtypes
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
df.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
df.count()
# Out:
# Formatted Date              96453
# Summary                     96453
# Precip Type                 95936
# Temperature (C)             96453
# Apparent Temperature (C)    96453
# Humidity                    96453
# Wind Speed (km/h)           96453
# Wind Bearing (degrees)      96453
# Visibility (km)             96453
# Loud Cover                  96453
# Pressure (millibars)        96453
# Daily Summary               96453
# dtype: int64

# %%
df.isnull()
# Out:
#        Formatted Date  Summary  Precip Type  Temperature (C)  \
# 0               False    False        False            False
# 1               False    False        False            False
# 2               False    False        False            False
# 3               False    False        False            False
# 4               False    False        False            False
# ...               ...      ...          ...              ...
# 96448           False    False        False            False
# 96449           False    False        False            False
# 96450           False    False        False            False
# 96451           False    False        False            False
# 96452           False    False        False            False
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                         False     False              False
# 1                         False     False              False
# ...

# %%
df.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 24

# %%
df.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
df["Apparent Temperature (C)"]
# Out:
# 0         7.388889
# 1         7.227778
# 2         9.377778
# 3         5.944444
# 4         6.977778
#            ...
# 96448    26.016667
# 96449    24.583333
# 96450    22.038889
# 96451    21.522222
# 96452    20.438889
# Name: Apparent Temperature (C), Length: 96453, dtype: float64

# %%
df.loc[:, "Apparent Temperature (C)"]
# Out:
# 0         7.388889
# 1         7.227778
# 2         9.377778
# 3         5.944444
# 4         6.977778
#            ...
# 96448    26.016667
# 96449    24.583333
# 96450    22.038889
# 96451    21.522222
# 96452    20.438889
# Name: Apparent Temperature (C), Length: 96453, dtype: float64

# %%
df["Apparent Temperature (C)"].value_counts()
# Out:
#  12.777778    378
#  17.777778    373
#  13.888889    342
#  17.222222    330
#  12.222222    305
#              ...
#  35.355556      1
# -16.316667      1
# -12.038889      1
# -12.133333      1
#  34.600000      1
# Name: Apparent Temperature (C), Length: 8984, dtype: int64

# %%
df["Apparent Temperature (C)"].dtype
# Out:
# dtype('float64')

# %%
df["Apparent Temperature (C)"].dtypes
# Out:
# dtype('float64')

# %%
df.loc[ [10,20] ,["Precip Type", "Loud Cover"] ]
# Out:
#    Precip Type  Loud Cover
# 10        rain         0.0
# 20        rain         0.0

# %%
x = df.loc[10:20, "Humidity"]

# %%
x
# Out:
# 10    0.67
# 11    0.54
# 12    0.55
# 13    0.51
# 14    0.47
# 15    0.46
# 16    0.60
# 17    0.63
# 18    0.69
# 19    0.70
# 20    0.77
# Name: Humidity, dtype: float64

# %%
for i in x:
    if i == 0.55:
        continue
    else:
        print(i)
# Out:
# 0.67
# 0.54
# 0.51
# 0.47
# 0.46
# 0.6
# 0.63
# 0.69
# 0.7
# 0.77

# %%
df.loc[[1,3,5,7,9], ["Precip Type", "Humidity"]]
# Out:
#   Precip Type  Humidity
# 1        rain      0.86
# 3        rain      0.83
# 5        rain      0.85
# 7        rain      0.89
# 9        rain      0.72

# %%
df.loc[10:20, :]
# Out:
#                    Formatted Date        Summary Precip Type  Temperature (C)  \
# 10  2006-04-01 10:00:00.000 +0200  Partly Cloudy        rain        16.016667
# 11  2006-04-01 11:00:00.000 +0200  Partly Cloudy        rain        17.144444
# 12  2006-04-01 12:00:00.000 +0200  Partly Cloudy        rain        17.800000
# 13  2006-04-01 13:00:00.000 +0200  Partly Cloudy        rain        17.333333
# 14  2006-04-01 14:00:00.000 +0200  Partly Cloudy        rain        18.877778
# 15  2006-04-01 15:00:00.000 +0200  Partly Cloudy        rain        18.911111
# 16  2006-04-01 16:00:00.000 +0200  Partly Cloudy        rain        15.388889
# 17  2006-04-01 17:00:00.000 +0200  Mostly Cloudy        rain        15.550000
# 18  2006-04-01 18:00:00.000 +0200  Mostly Cloudy        rain        14.255556
# 19  2006-04-01 19:00:00.000 +0200  Mostly Cloudy        rain        13.144444
# 20  2006-04-01 20:00:00.000 +0200  Mostly Cloudy        rain        11.550000
#
# ...

# %%
df.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
df.set_index("Formatted Date")
# Out:
#                                      Summary Precip Type  Temperature (C)  \
# Formatted Date
# 2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
# ...                                      ...         ...              ...
# 2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain        26.016667
# 2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain        24.583333
# 2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain        22.038889
# 2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain        21.522222
# 2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain        20.438889
#
# ...

# %%
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
df.head(1)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.

# %%
df.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=96453, step=1)

# %%
df.iloc[0:5, 4]
# Out:
# 0    7.388889
# 1    7.227778
# 2    9.377778
# 3    5.944444
# 4    6.977778
# Name: Apparent Temperature (C), dtype: float64

# %%
df.loc[0, ["Summary", "Temperature (C)", "Wind Speed (km/h)"]]
# Out:
# Summary              Partly Cloudy
# Temperature (C)           9.472222
# Wind Speed (km/h)        14.119700
# Name: 0, dtype: object

# %%
x = df.loc[0:150, ["Temperature (C)","Visibility (km)", "Humidity"]]
x.head(10)
x.isnull().sum()
# Out:
# Temperature (C)    0
# Visibility (km)    0
# Humidity           0
# dtype: int64

# %%
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
x = df.set_index("Humidity")
x
# Out:
#                          Formatted Date        Summary Precip Type  \
# Humidity
# 0.89      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 0.86      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 0.89      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 0.83      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 0.83      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                                 ...            ...         ...
# 0.43      2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 0.48      2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 0.56      2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 0.60      2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 0.61      2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#           Temperature (C)  Apparent Temperature (C)  Wind Speed (km/h)  \
# Humidity
# ...

# %%
df.sort_index(axis=0)
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
df.sort_index(axis=1)
# Out:
#        Apparent Temperature (C)                           Daily Summary  \
# 0                      7.388889       Partly cloudy throughout the day.
# 1                      7.227778       Partly cloudy throughout the day.
# 2                      9.377778       Partly cloudy throughout the day.
# 3                      5.944444       Partly cloudy throughout the day.
# 4                      6.977778       Partly cloudy throughout the day.
# ...                         ...                                     ...
# 96448                 26.016667  Partly cloudy starting in the morning.
# 96449                 24.583333  Partly cloudy starting in the morning.
# 96450                 22.038889  Partly cloudy starting in the morning.
# 96451                 21.522222  Partly cloudy starting in the morning.
# 96452                 20.438889  Partly cloudy starting in the morning.
#
#                       Formatted Date  Humidity  Loud Cover Precip Type  \
# ...

# %%
df.sort_index( ascending=True, axis=1)
# Out:
#        Apparent Temperature (C)                           Daily Summary  \
# 0                      7.388889       Partly cloudy throughout the day.
# 1                      7.227778       Partly cloudy throughout the day.
# 2                      9.377778       Partly cloudy throughout the day.
# 3                      5.944444       Partly cloudy throughout the day.
# 4                      6.977778       Partly cloudy throughout the day.
# ...                         ...                                     ...
# 96448                 26.016667  Partly cloudy starting in the morning.
# 96449                 24.583333  Partly cloudy starting in the morning.
# 96450                 22.038889  Partly cloudy starting in the morning.
# 96451                 21.522222  Partly cloudy starting in the morning.
# 96452                 20.438889  Partly cloudy starting in the morning.
#
#                       Formatted Date  Humidity  Loud Cover Precip Type  \
# ...

# %%
df.sort_index( ascending=False, axis=1)
# Out:
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# 0                14.1197                   251.0          15.8263
# 1                14.2646                   259.0          15.8263
# 2                 3.9284                   204.0          14.9569
# 3                14.1036                   269.0          15.8263
# 4                11.0446                   259.0          15.8263
# ...                  ...                     ...              ...
# 96448            10.9963                    31.0          16.1000
# 96449            10.0947                    20.0          15.5526
# 96450             8.9838                    30.0          16.1000
# 96451            10.5294                    20.0          16.1000
# 96452             5.8765                    39.0          15.5204
#
#        Temperature (C)        Summary  Pressure (millibars) Precip Type  \
# 0             9.472222  Partly Cloudy               1015.13        rain
# ...

# %%
df.sort_values("Temperature (C)", ascending=False)
# Out:
#                       Formatted Date        Summary Precip Type  \
# 12759  2007-07-22 15:00:00.000 +0200          Clear        rain
# 12737  2007-07-21 17:00:00.000 +0200  Partly Cloudy        rain
# 12664  2007-07-19 16:00:00.000 +0200  Partly Cloudy        rain
# 12712  2007-07-20 16:00:00.000 +0200  Partly Cloudy        rain
# 12711  2007-07-20 15:00:00.000 +0200  Partly Cloudy        rain
# ...                              ...            ...         ...
# 55495  2012-02-09 07:00:00.000 +0100          Foggy        snow
# 55494  2012-02-09 06:00:00.000 +0100          Foggy        snow
# 55493  2012-02-09 05:00:00.000 +0100          Foggy        snow
# 55490  2012-02-09 02:00:00.000 +0100          Foggy        snow
# 54847  2012-02-10 07:00:00.000 +0100          Foggy        snow
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 12759        39.905556                 37.538889      0.13            23.5865
# ...

# %%
fltr = df["Daily Summary"].str.contains("Foggy until morning", na=False)

# %%
df.loc[fltr, "Daily Summary"]
# Out:
# 1968     Foggy until morning.
# 1969     Foggy until morning.
# 1970     Foggy until morning.
# 1971     Foggy until morning.
# 1972     Foggy until morning.
#                  ...
# 95391    Foggy until morning.
# 95392    Foggy until morning.
# 95393    Foggy until morning.
# 95394    Foggy until morning.
# 95395    Foggy until morning.
# Name: Daily Summary, Length: 2691, dtype: object

# %%
df.loc[fltr, "Daily Summary"].count()
# Out:
# 2691

# %%
df.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
fltr = (df["Wind Bearing (degrees)"] >250 )

# %%
df.loc[fltr]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# 5      2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain
# ...                              ...            ...         ...
# 96426  2016-09-08 21:00:00.000 +0200  Mostly Cloudy        rain
# 96427  2016-09-08 22:00:00.000 +0200  Partly Cloudy        rain
# 96430  2016-09-09 01:00:00.000 +0200          Clear        rain
# 96433  2016-09-09 04:00:00.000 +0200          Clear        rain
# 96434  2016-09-09 05:00:00.000 +0200          Clear        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
fltr = (df["Wind Bearing (degrees)"] >250 ) & (df["Wind Bearing (degrees)"] <252 )

# %%
df[fltr]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 16     2006-04-01 16:00:00.000 +0200  Partly Cloudy        rain
# 180    2006-04-16 12:00:00.000 +0200       Overcast        rain
# 278    2006-04-02 14:00:00.000 +0200  Partly Cloudy        rain
# 1104   2006-08-24 00:00:00.000 +0200  Partly Cloudy        rain
# ...                              ...            ...         ...
# 94543  2016-11-02 11:00:00.000 +0100  Mostly Cloudy         NaN
# 95537  2016-10-03 21:00:00.000 +0200       Overcast        rain
# 95599  2016-10-04 10:00:00.000 +0200       Overcast        rain
# 95700  2016-10-08 15:00:00.000 +0200  Mostly Cloudy        rain
# 96351  2016-09-05 18:00:00.000 +0200  Mostly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
fltr = df["Precip Type"].str.contains("Rain", na=False)

# %%
df.loc[fltr, "Summary"]
# Out:
# Series([], Name: Summary, dtype: object)

# %%
fltr = (df["Summary"] == "Mostly Cloudy")

# %%
df.loc[fltr, ["Humidity", "Formatted Date"]]
# Out:
#        Humidity                 Formatted Date
# 2          0.89  2006-04-01 02:00:00.000 +0200
# 4          0.83  2006-04-01 04:00:00.000 +0200
# 17         0.63  2006-04-01 17:00:00.000 +0200
# 18         0.69  2006-04-01 18:00:00.000 +0200
# 19         0.70  2006-04-01 19:00:00.000 +0200
# ...         ...                            ...
# 96412      0.85  2016-09-08 07:00:00.000 +0200
# 96413      0.78  2016-09-08 08:00:00.000 +0200
# 96415      0.55  2016-09-08 10:00:00.000 +0200
# 96416      0.45  2016-09-08 11:00:00.000 +0200
# 96426      0.64  2016-09-08 21:00:00.000 +0200
#
# [28094 rows x 2 columns]
